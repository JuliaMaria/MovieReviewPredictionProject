# %%
import numpy as np
import pickle
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import matplotlib.pyplot as plt

# %%
rand = np.random.RandomState(34215)

# %%
data = np.load('preprocessed_data_new.npy')

# %%
clf = pickle.load(open("best_movies.pkl", "rb"))

# %%
X = data[:, :-1]
y = data[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
actuals = y_test

# %%
predictions = clf.predict(X_test)
print('MSE: {}'.format(mean_squared_error(actuals, predictions)))
print('RMSE: {}'.format(np.sqrt(mean_squared_error(actuals, predictions))))
print('MAE: {}'.format(mean_absolute_error(actuals, predictions)))
print('R2: {}'.format(r2_score(actuals, predictions)))
# Out:
# MSE: 0.5137510044416175
# RMSE: 0.7167642600197205
# MAE: 0.5616956795476804
# R2: 0.312384126617107

# %%
plt.scatter(actuals, predictions)
plt.plot(range(3, 10), range(3, 10))
plt.xlabel('label')
plt.ylabel('predition')
plt.show()

# %%
plt.plot(clf.feature_importances_)

# %%
clf.feature_importances_.argsort()[-10:][::-1]
# Out:
# array([1521, 1515, 1502, 1516,  311, 1514,  354,  445, 1508, 1051],
#       dtype=int64)
